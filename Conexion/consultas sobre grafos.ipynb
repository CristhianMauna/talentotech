# %% [markdown]
# Ejercicios en clase/casa (Consultar y Desarrollar):
#
# 0. Qué es teoría de grafos (dar ejemplos de grafos), cuáles son los tipos de grafos (grafo no dirigido, grafo dirigido), y las características de los grafos: adyacencia (A), incidencia (consultar la matriz de incidencia I), grado de un vértice (consultar la ley "hand shaking"), trayectoria.
#
# 1. Definiciones de las matrices A, R y dij
#
# 2. Cómo hacer la multiplicación entre dos matrices manualmente
#
# (Ayuda: recordar el producto punto entre filas de la primera matriz y columnas de la segunda matriz)
#
# 3. Algoritmo de Dijkstra
#
# 4. Algoritmo de Yen
#
# 5. Inventarse dos grafos y hacer todo el análisis a ambos
#
# 6. Hacer todo el análisis del grafo de Euler

# %% [markdown]
# Respuesta 0: la teoría de grafos es una rama de las matemáticas y la informática que estudia las relaciones entre objetos.
#
# un grafo es una estructura compuesta por:
# vertices(nodos): Representan objestos o entidades
#
# Aristas (enlaces): Representan relaciones o conexiones entre los vertices.
#
# Ejemplos de grafos:
# 1. Red social: son personas como nodo, y amistades como aristas
# 2. mapa de carreteras: Ciudades como nodos, y carreteras como aristas.
# 3. Internet: son las conexiones de sitios web como nodos y enlaces como aristas.
#
# Tipos de grafos
# 1. Grafo no dirigido
# Las aristas no tienen dirección.
# Ejemplo: Una amistad mutua entre dos personas.
# A --- B
#
# 1. Grafo no dirigido
# Las aristas no tienen dirección.
# Ejemplo: Una amistad mutua entre dos personas.
# A → B
#
#  Características de los grafos
# 1. Matriz de adyacencia (A)
# Es una matriz cuadrada donde:
# A[i][j]=1 si hay una arista de
# i
# i a
# j
# j.
# A
# [
# i
# ]
# [
# j
# ]
# =
# 0
# A[i][j]=0 si no hay conexión.
#
# 2. Matriz de incidencia (I)
# Relaciona vértices con aristas.
# En grafos dirigidos:
# I
# [
# i
# ]
# [
# e
# ]
# =
# −
# 1
# I[i][e]=−1 si el vértice
# i
# i es el origen de la arista
# e
# e.
# I
# [
# i
# ]
# [
# e
# ]
# =
# 1
# I[i][e]=1 si el vértice
# i
# i es el destino.
# I
# [
# i
# ]
# [
# e
# ]
# =
# 0
# I[i][e]=0 si no está conectado a la arista.
#
# 3. Grado de un vértice
# Grafo no dirigido:
# Grado: número de aristas conectadas al vértice.
# Grafo dirigido:
# Grado de entrada (in-degree): número de aristas que llegan al vértice.
# Grado de salida (out-degree): número de aristas que salen del vértice.
#
# Ley der apreton de manos (Handshaing Lemma)
# en un grafo no dirigido:
# la suma de los grafos de todos los vértices es igual al doble de aristas
#
# la formula seria
#  ∑ grado(v)=2⋅∣E∣
#
# trayectoria (camino)
# una trayectoria es una secuencia de vértices conectados por aristas.
# puede ser una longitud 1 (una arista) o mas
# si empieza y termina en el mismo nodo, y no repite aristas, es un ciclo.

# %% [markdown]
# Definiciones de las matrices A, R y dij
#
#  Matriz de Adyacencia (A)
# La matriz de adyacencia
# 𝐴
# A representa las conexiones directas entre nodos de un grafo.
#
# Si hay una arista entre el nodo
# 𝑖
# i y el nodo
# 𝑗
# j, entonces
# 𝐴
# [
# 𝑖
# ]
# [
# 𝑗
# ]
# =
# 1
# A[i][j]=1, de lo contrario,
# 𝐴
# [
# 𝑖
# ]
# [
# 𝑗
# ]
# =
# 0
# A[i][j]=0.
#
# En grafos dirigidos,
# 𝐴
# [
# 𝑖
# ]
# [
# 𝑗
# ]
# =
# 1
# A[i][j]=1 significa una arista de
# 𝑖
# →
# 𝑗
# i→j.
#
# En grafos no dirigidos, la matriz es simétrica:
# 𝐴
# [
# 𝑖
# ]
# [
# 𝑗
# ]
# =
# 𝐴
# [
# 𝑗
# ]
# [
# 𝑖
# ]
# A[i][j]=A[j][i].
#
# Matriz de Caminos o Alcance (R)
# La matriz de caminos o matriz de accesibilidad
# 𝑅
# R (a veces llamada de conectividad) indica si existe algún camino entre dos nodos, sin importar la longitud del camino.
#
# 𝑅
# [
# 𝑖
# ]
# [
# 𝑗
# ]
# =
# 1
# R[i][j]=1 si existe algún camino (de cualquier longitud
# ≥
# 1
# ≥1) de
# 𝑖
# i a
# 𝑗
# j.
#
# Puede obtenerse como la suma de las potencias de
# 𝐴
# A:
#
# 𝑅
# =
# 𝐴
# +
# 𝐴
# 2
# +
# 𝐴
# 3
# +
# ⋯
# +
# 𝐴
# 𝑛
# R=A+A
# 2
#  +A
# 3
#  +⋯+A
# n
#
# (normalmente se toma el resultado como binario: 1 si el valor es mayor que 0).
#
#  Matriz de Distancias (D o dij)
# La matriz de distancias
# 𝐷
# =
# [
# 𝑑
# 𝑖
# 𝑗
# ]
# D=[d
# ij
# ​
#  ] representa la longitud mínima del camino entre cada par de nodos.
#
# 𝑑
# 𝑖
# 𝑗
# d
# ij
# ​
#   es el número mínimo de aristas entre el nodo
# 𝑖
# i y el nodo
# 𝑗
# j.
#
# Si no hay camino, se coloca un valor infinito
# ∞
# ∞ o un número muy grande.
#
# Puede calcularse con algoritmos como Floyd-Warshall o Dijkstra (para grafos ponderados).

# %% [markdown]
# Cómo hacer la multiplicación entre dos matrices manualmente
#
# (Ayuda: recordar el producto punto entre filas de la primera matriz y columnas de la segunda matriz)
#
# la multiplicacionde dos matrices se hace fila por columna, usando el produco.
#
# paso a paso. multiplicación de matrices
# supongamos que se tiene estas dos matrices
#
# ![Captura de pantalla 2025-06-18 113312.png](data:image/png;base64,...)

# %% [markdown]
# para multiplicarlas, se debe hacer el producto punto entre cada fila de A y cada columna de B
# el resultado será una nueva matriz C= A*B de tamaño 2x2
#
# Cálculo manual
#
# C[0][0]=(1*5)+(2*7)= 5+14 =19
#
# C[0][1]=(1*6)+(2*8)= 6+16 =22
#
# C[1][0]=(3*5)+(4*7)= 15+28 =43
#
# C[1][1]=(3*6)+(4*8)= 18+32 =50
#
# Resultado se expresa de la siguiente manera
#
# ![Captura de pantalla 2025-06-18 114150.png](data:image/png;base64,...)

# %% [markdown]
# 3. Algoritmo de Dijkstra
# el algoritmo de Dijkstra es un método para encontrar el camino más corto desde un nodo origen a todos los demás nodos en un grafo ponderado (es decir, con pesos en las aristas), siempre que los pesos sean no negativos.
#
# ¿para qué sirve?
# nos sirve para encontrar la ruta más corta entre dos puntos (por ejemplo, en mapas, redes rutas de entrega).
#
# y tambien nos sirve para calcular distancias mínimas desde un nodo origen a todos los demas.
#
# ¿como funciona?
#
# 1. Inicializa las distancias desde el nodo origen a todos los demás como (infinito), excepto la del nodo origen, que es 0.
#
# 2. Marca todos los nodos como no visitados.
#
# 3. Elige el nodo no visitado con la menor distancia conocida.
#
# 4. Actualiza las distancias de sus vecinos si el nuevo camino es más corto.
#
# 5. Marca el nodo como visitado
#
# 6. repite desde el paso 3 hasta que todos los nodos hayan sido visítados.

# %% [markdown]
# Algoritmo de Yen
#
# El algoritmo de Yen es un método utilizado para encontrar los k caminos más cortos (no necesariamente únicos) entre un nodo origen y un nodo destino en un grafo dirigido o no dirigido, ponderado y sin ciclos negativos.
#
#
# ¿Para qué sirve?
#
# Para obtener varias rutas alternativas, no solo la más corta.
# Es útil en:
#
# Redes de telecomunicaciones (rutas alternativas si una falla).
#
# Sistemas de navegación (opciones de rutas).
#
# Logística y transporte.
#
# ¿Cómo funciona?
#
# Encuentra el camino más corto desde el origen hasta el destino (usando Dijkstra, por ejemplo). Ese es el primer camino.
#
# Luego, genera caminos "desviados" (llamados k-spur paths) tomando diferentes puntos intermedios del primer camino.
#
# Para cada desviación, se evita parte del camino anterior (para obtener una ruta diferente).
#
# Se guarda cada nuevo camino en una lista ordenada.
#
# Se repite el proceso hasta encontrar los k caminos más cortos.
#
# algunas ventajas del algorítmo de yen pueden ser encontrar múltiples rutas eficientes.
#
# Garantizar orden por costo (del más corto al más largo).
#
# Es muy util para algorítmos de ruteo resiliente.

# %%
#Inventarse dos grafos y hacer todo el análisis a ambos
#Grafo 1 no dirigido y ponderado

      (A)
     /   \
   2/     \3
   /       \
 (B)---1---(C)
   \       /
   4\     /2
     \   /
      (D)

#Matriz de adyacencia ponderada:
    A  B  C  D
A [ 0, 2, 3, 0 ]
B [ 2, 0, 1, 4 ]
C [ 3, 1, 0, 2 ]
D [ 0, 4, 2, 0 ]

# %% [markdown]
#  Análisis:
#
# Conectado: Sí, todos los nodos están conectados directa o indirectamente.
#
# Ciclo mínimo: A–B–C–A (2 + 1 + 3 = 6)
#
# Camino más corto A→D (Dijkstra):
#
# A → C → D = 3 + 2 = 5
#
# Matriz de distancias (dᵢⱼ):

# %%
    A  B  C  D
A [ 0, 2, 3, 5 ]
B [ 2, 0, 1, 3 ]
C [ 3, 1, 0, 2 ]
D [ 5, 3, 2, 0 ]

# %%
#Grafo 2 dirigido y ponderado
 (A) →5→ (B) →3→ (D)
 ↓3           ↑2
(C) →1→───────┘

# %%
#Matriz de adyacencia ponderada
    A  B  C  D
A [ 0, 5, 3, 0 ]
B [ 0, 0, 0, 3 ]
C [ 0, 0, 0, 1 ]
D [ 0, 0, 0, 0 ]

# %% [markdown]
#  Análisis:
#
# Dirigido: Sí, las aristas tienen dirección.
#
# No fuertemente conexo: No se puede llegar a todos los nodos desde todos.
#
# Camino más corto A→D (Dijkstra):
#
# A → C → D = 3 + 1 = 4 (más corto que A→B→D)
#
# Matriz de distancias (dᵢⱼ):
#
#     A  B  C  D
# A [ 0, 5, 3, 4 ]
#
# B [ ∞, 0, ∞, 3 ]
#
# C [ ∞, ∞, 0, 1 ]
#
# D [ ∞, ∞, ∞, 0 ]
