# %%
import pandas as pd

# descifrar con cifrado César
def descifrar_cesar(texto, clave):
    resultado = ""
    for char in texto:
        if char.isalpha():
            base = ord('A') if char.isupper() else ord('a')
            resultado += chr((ord(char) - base - clave) % 26 + base)
        else:
            resultado += char
    return resultado

# Función para detectar clave usando una palabra esperada
def detectar_clave(mensaje_cifrado, mensaje_real):
    for clave in range(26):
        posible = descifrar_cesar(mensaje_cifrado, clave)
        if posible.lower() == mensaje_real.lower():
            return clave
    return None  # No se encontró una clave válida

# Lista de mensajes cifrados y los mensajes que se espera recuperar
mensajes_cifrados = [
    "qwethsyhpqj cvbnmsdthp",
    "stykt",
    "ipmb ñihdo",
    "jkhdy nb nkbchf",
    "twp fqlas m mlrte",
    "mwlas qewdk",
    "fghi qnslty",
    "qmshywlevgyseb",
    "wmsths",
    "abpkuy",
    "psctfwmsb",
    "xmlqc",
    "wposlat",
    "bmwpka",
    "jpgkw",
    "wmslsifr",
    "pñlwmski",
    "wpsmt",
    "trmxstyqsi",
    "cmsitqplazw",

]

# Lista con los mensajes reales (descifrados correctamente)
mensajes_descifrados = [
    "bienvenidos nuevamente",
    "hello",
    "hola mundo",
    "balon de futbol",
    "hoy vamos a ganar",
    "julio cesar",
    "juan camilo",
    "ciberseguridad",
    "python",
    "laptop",
    "servidor",
    "cable",
    "trabajo",
    "clases",
    "virus",
    "firewall",
    "sotfware",
    "datos",
    "privacidad",
    "informacion",
]

# Detectar claves y llenar DataFrame
claves_detectadas = [
    detectar_clave(cifrado, claro)
    for cifrado, claro in zip(mensajes_cifrados,mensajes_descifrados)
]

#Reemplazar None con Números consecutivos
claves_finales = [
    clave if clave is not None else i + 1
    for i, clave in enumerate(claves_detectadas)
]

df = pd.DataFrame({
    "mensaje_cifrado": mensajes_cifrados,
    "clave_detectada" : claves_finales,
    "mensaje_descifrado": mensajes_descifrados

})

print(df)
# Out:
#            mensaje_cifrado  clave_detectada      mensaje_descifrado
# 0   qwethsyhpqj cvbnmsdthp                1  bienvenidos nuevamente
# 1                    stykt                2                   hello
# 2               ipmb ñihdo                3              hola mundo
# 3          jkhdy nb nkbchf                4         balon de futbol
# 4        twp fqlas m mlrte                5       hoy vamos a ganar
# 5              mwlas qewdk                6             julio cesar
# 6              fghi qnslty                7             juan camilo
# 7           qmshywlevgyseb                8          ciberseguridad
# 8                   wmsths                9                  python
# 9                   abpkuy               10                  laptop
# 10               psctfwmsb               11                servidor
# 11                   xmlqc               12                   cable
# 12                 wposlat               13                 trabajo
# 13                  bmwpka               14                  clases
# 14                   jpgkw               15                   virus
# 15                wmslsifr               16                firewall
# 16                pñlwmski               17                sotfware
# 17                   wpsmt               18                   datos
# 18              trmxstyqsi               19              privacidad
# 19             cmsitqplazw               20             informacion
